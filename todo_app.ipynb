# %% [markdown]
# <a href="https://colab.research.google.com/github/raziarasheed/Guess-the-Number-Game-Python-Project-computer-/blob/main/todo_app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import os

TASKS_FILE = 'tasks.json'

def load_tasks():
    if os.path.exists(TASKS_FILE):
        with open(TASKS_FILE, 'r') as f:
            return json.load(f)
    return []

def save_tasks(tasks):
    with open(TASKS_FILE, 'w') as f:
        json.dump(tasks, f, indent=4)

def list_tasks(tasks):
    if not tasks:
        print("No tasks found.")
    else:
        print("\nCurrent Tasks:")
        for task in tasks:
            print(f"ID: {task['id']} | Description: {task['description']}")
        print()

def add_task(tasks):
    description = input("Enter task description: ").strip()
    if description:
        task_id = max([task['id'] for task in tasks], default=0) + 1
        tasks.append({'id': task_id, 'description': description})
        save_tasks(tasks)
        print(f"Task added with ID: {task_id}")
    else:
        print("Task description cannot be empty.")

def delete_task(tasks):
    try:
        task_id = int(input("Enter task ID to delete: "))
        for task in tasks:
            if task['id'] == task_id:
                tasks.remove(task)
                save_tasks(tasks)
                print(f"Task with ID {task_id} deleted.")
                return
        print(f"No task found with ID {task_id}.")
    except ValueError:
        print("Invalid ID. Please enter a number.")

def update_task(tasks):
    try:
        task_id = int(input("Enter task ID to update: "))
        for task in tasks:
            if task['id'] == task_id:
                new_description = input("Enter new task description: ").strip()
                if new_description:
                    task['description '] = new_description
                    save_tasks(tasks)
                    print(f"Task with ID {task_id} updated.")
                else:
                    print("Task description cannot be empty.")
                return
        print(f"No task found with ID {task_id}.")
    except ValueError:
        print("Invalid ID. Please enter a number.")

def main():
    tasks = load_tasks()
    while True:
        print("\nTo-Do List Application")
        print("1. List Tasks ")
        print("2. Add Task ")
        print("3. Delete Task ")
        print("4. Update Task")
        print("5. Exit")
        choice = input("Enter your choice (1-5): ").strip()
        if choice == '1':
            list_tasks(tasks)
        elif choice == '2':
            add_task(tasks)
        elif choice == '3':
            delete_task(tasks)
        elif choice == '4':
            update_task(tasks)
        elif choice == '5':
            print("Exiting application. Goodbye!")
            break
        else:
            print("Invalid choice. Please enter a number between 1 and 5.")

if __name__ == "__main__":
    main()
# Out:
# To-Do List Application
# 1. List Tasks
# 2. Add Task
# 3. Delete Task
# 4. Update Task
# 5. Exit
# Enter your choice (1-5): 1
#
# Current Tasks:
# ID: 1 | Description: 2
# ID: 2 | Description: 3
#
#
# To-Do List Application
# 1. List Tasks
# 2. Add Task
# 3. Delete Task
# 4. Update Task
# 5. Exit
# Enter your choice (1-5): 2
# Enter task description: id
# Task added with ID: 3
#
# To-Do List Application
# 1. List Tasks
# 2. Add Task
# 3. Delete Task
# 4. Update Task
# 5. Exit
# Enter your choice (1-5): 2
# Enter task description: 4
# Task added with ID: 4
#
# To-Do List Application
# 1. List Tasks
# 2. Add Task
# 3. Delete Task
# 4. Update Task
# 5. Exit
# Enter your choice (1-5): 5
# Exiting application. Goodbye!
